# %%
from crewai import Agent, Task, Crew, LLM
from crewai_tools import SerperDevTool
# import groq
from crewai_tools import SerperDevTool


from dotenv import load_dotenv
import os
load_dotenv()
GROQ_API_KEY = os.getenv("GROQ_API_KEY")
from crewai import Agent, Task, Crew, LLM

# Initialize Large Language Model (LLM) of your choice (see all models on our Models page)
llm = LLM(model="groq/llama-3.1-70b-versatile")


search_tool = SerperDevTool()

# Create your CrewAI agents with role, main goal/objective, and backstory/personality
summarizer = Agent(
    role='Documentation Summarizer', # Agent's job title/function
    goal='Create concise summaries of technical documentation', # Agent's main objective
    backstory='Technical writer who excels at simplifying complex concepts', # Agent's background/expertise
    llm=llm, # LLM that powers your agent
    verbose=True # Show agent's thought process as it completes its task
)

translator = Agent(
    role='Technical Translator',
    goal='Translate technical documentation to other languages',
    backstory='Technical translator specializing in software documentation',
    llm=llm,
    verbose=True
)

# Define your agents' tasks
summary_task = Task(
    description='Summarize this React hook documentation:\n\nuseFetch(url) is a custom hook for making HTTP requests. It returns { data, loading, error } and automatically handles loading states.',
    expected_output="A clear, concise summary of the hook's functionality",
    agent=summarizer # Agent assigned to task
)

translation_task = Task(
    description='Translate the summary to Turkish',
    expected_output="Turkish translation of the hook documentation",
    agent=translator,
    dependencies=[summary_task] # Must run after the summary task
)

# Create crew to manage agents and task workflow
crew = Crew(
    agents=[summarizer, translator], # Agents to include in your crew
    tasks=[summary_task, translation_task], # Tasks in execution order
    verbose=True
)

result = crew.kickoff()
print(result)
# Out:
# 2025-01-24 23:09:33,182 - 17488 - __init__.py-__init__:537 - WARNING: Overriding of current TracerProvider is not allowed
# LLM value is already an LLM object
# LLM value is already an LLM object
# # Agent: Documentation Summarizer
# ## Task: Summarize this React hook documentation:
#
# useFetch(url) is a custom hook for making HTTP requests. It returns { data, loading, error } and automatically handles loading states.
#
#
# # Agent: Documentation Summarizer
# ## Final Answer:
# The useFetch(url) hook is a custom React hook designed to simplify the process of making HTTP requests within React applications. It automatically manages the loading state of the request, providing a straightforward way to handle data fetching. When invoked, useFetch(url) returns an object containing three key properties: data, loading, and error.
#
# - The "data" property holds the response data from the successful HTTP request, which can be used to render or process the fetched information within the component.
# - The "loading" property is a boolean indicator that signifies whether the HTTP request is currently in progress. This can be utilized to conditionally render loading indicators, such as spinners or skeletons, to enhance the user experience during the data fetching process.
# - The "error" property contains any error that might occur during the request, allowing developers to handle and display error messages appropriately, thus improving the overall robustness and user feedback of the application.
#
# By using useFetch(url), developers can easily integrate data fetching into their React components without manually handling the intricacies of request states, focusing more on the component's logic and user interface. This hook streamlines the process of fetching data, making it easier to manage asynchronous operations and improve code readability and maintainability.
#
#
# # Agent: Technical Translator
# ## Task: Translate the summary to Turkish
#
#
# # Agent: Technical Translator
# ## Final Answer:
# useFetch(url) hook, özel olarak React uygulamaları içerisinde HTTP isteklerinin yapılma sürecini basitleştirmek için tasarlanmış bir özel React hook'tur. İsteklerin yüklenme durumunu otomatik olarak yönetir ve verilerin alınmasını kolay bir şekilde gerçekleştirir. useFetch(url) çağırıldığında, üç ana özelliği içeren bir nesne döndürür: data, loading ve error.
#
# - "data" özelliği, başarılı HTTP isteğinden gelen réponse verilerini tutar ve bu veriler, bileşen içerisinde alınan bilgilerin işlenmesine veya 렌derlenmesine kullanılabilir.
# - "loading" özelliği, bir boolean göstergesi olup, HTTP isteğinin当前是否 devam ettiği gösterir. Bu, veri alma sırasında kullanıcı deneyisini cải thiện etmek için yüklenme göstergeleri, Örneğin, spinners veya iskeletler gibi şeylerin koşullu olarak 렌derlenmesine olanak tanır.
# - "error" özelliği, istek sırasında oluşabilecek herhangi bir hatayı içerir, böylece geliştiriciler hata mesajlarını uygun bir şekilde ele alabilir ve görüntüleyebilir, böylece uygulamanın genel dayanıklılığı ve kullanıcı geri bildirimi cảiştirilir.
#
# useFetch(url) kullanarak, geliştiriciler, istek durumlarının karmaşıklıkları ile manuel olarak uğraşmak zorunda kalmadan, kolayca veri alma işlemini React bileşenlerine entegre edebilir ve daha çok bileşenin mantığı ve kullanıcı arayüzü üzerine odaklanabilir. Bu hook, veri alma sürecini basitleştirir ve aynı zamanda asenkron işlemlerin yönetimini kolaylaştırır, kodu daha okunabilir ve mantener hale getirir.
#
#
# useFetch(url) hook, özel olarak React uygulamaları içerisinde HTTP isteklerinin yapılma sürecini basitleştirmek için tasarlanmış bir özel React hook'tur. İsteklerin yüklenme durumunu otomatik olarak yönetir ve verilerin alınmasını kolay bir şekilde gerçekleştirir. useFetch(url) çağırıldığında, üç ana özelliği içeren bir nesne döndürür: data, loading ve error.
#
# - "data" özelliği, başarılı HTTP isteğinden gelen réponse verilerini tutar ve bu veriler, bileşen içerisinde alınan bilgilerin işlenmesine veya 렌derlenmesine kullanılabilir.
# - "loading" özelliği, bir boolean göstergesi olup, HTTP isteğinin当前是否 devam ettiği gösterir. Bu, veri alma sırasında kullanıcı deneyisini cải thiện etmek için yüklenme göstergeleri, Örneğin, spinners veya iskeletler gibi şeylerin koşullu olarak 렌derlenmesine olanak tanır.
# - "error" özelliği, istek sırasında oluşabilecek herhangi bir hatayı içerir, böylece geliştiriciler hata mesajlarını uygun bir şekilde ele alabilir ve görüntüleyebilir, böylece uygulamanın genel dayanıklılığı ve kullanıcı geri bildirimi cảiştirilir.
#
# useFetch(url) kullanarak, geliştiriciler, istek durumlarının karmaşıklıkları ile manuel olarak uğraşmak zorunda kalmadan, kolayca veri alma işlemini React bileşenlerine entegre edebilir ve daha çok bileşenin mantığı ve kullanıcı arayüzü üzerine odaklanabilir. Bu hook, veri alma sürecini basitleştirir ve aynı zamanda asenkron işlemlerin yönetimini kolaylaştırır, kodu daha okunabilir ve mantener hale getirir.
